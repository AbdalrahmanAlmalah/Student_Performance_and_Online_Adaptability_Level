# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder
np.set_printoptions(precision=2)

# %%
df = pd.read_csv('StudentMentalHealth.csv')
X = df[['Choose your gender', 'Age', 'What is your CGPA?', 'Marital status', 'Do you have Depression?']]
df.head()
# Out:
#           Timestamp Choose your gender  Age What is your course?  \
# 0  08/07/2020 12:02             Female   18          Engineering
# 1  08/07/2020 12:04               Male   21    Islamic education
# 2  08/07/2020 12:05               Male   19                  BIT
# 3  08/07/2020 12:06             Female   22                 Laws
# 4  08/07/2020 12:31               Male   19          Engineering
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     Year 2        3.50 - 4.00             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
l1 = LabelEncoder()
l1.fit(X[['Do you have Depression?']])
df['Do you have Depression?_res'] = l1.transform(df[['Do you have Depression?']])
df = df.drop('Do you have Depression?', axis=1)
df
# Out:
# c:\Users\zeina\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\zeina\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#            Timestamp Choose your gender  Age What is your course?  \
# 0   08/07/2020 12:02             Female   18          Engineering
# 1   08/07/2020 12:04               Male   21    Islamic education
# 2   08/07/2020 12:05               Male   19                  BIT
# 3   08/07/2020 12:06             Female   22                 Laws
# 4   08/07/2020 12:31               Male   19          Engineering
# ...

# %%
l1 = LabelEncoder()
l1.fit(X[['Marital status']])
df['Marital status_res'] = l1.transform(df[['Marital status']])
df = df.drop('Marital status', axis=1)
df
# Out:
# c:\Users\zeina\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\zeina\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#            Timestamp Choose your gender  Age What is your course?  \
# 0   08/07/2020 12:02             Female   18          Engineering
# 1   08/07/2020 12:04               Male   21    Islamic education
# 2   08/07/2020 12:05               Male   19                  BIT
# 3   08/07/2020 12:06             Female   22                 Laws
# 4   08/07/2020 12:31               Male   19          Engineering
# ...

# %%
l1 = LabelEncoder()
l1.fit(X[['Choose your gender']])
df['Choose your gender_res'] = l1.transform(df[['Choose your gender']])
df = df.drop('Choose your gender', axis=1)
df
# Out:
# c:\Users\zeina\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\zeina\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#            Timestamp  Age What is your course? Your current year of Study  \
# 0   08/07/2020 12:02   18          Engineering                     year 1
# 1   08/07/2020 12:04   21    Islamic education                     year 2
# 2   08/07/2020 12:05   19                  BIT                     Year 1
# 3   08/07/2020 12:06   22                 Laws                     year 3
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

e1 = OneHotEncoder(sparse=False)
res1= e1.fit_transform(df[['What is your CGPA?']])
df = pd.get_dummies(df, columns=['What is your CGPA?'])
df
# Out:
#            Timestamp  Age What is your course? Your current year of Study  \
# 0   08/07/2020 12:02   18          Engineering                     year 1
# 1   08/07/2020 12:04   21    Islamic education                     year 2
# 2   08/07/2020 12:05   19                  BIT                     Year 1
# 3   08/07/2020 12:06   22                 Laws                     year 3
# 4   08/07/2020 12:31   19          Engineering                     Year 2
# ..               ...  ...                  ...                        ...
# 93  13/07/2020 19:56   21                  BCS                     year 1
# 94  13/07/2020 21:21   18          Engineering                     Year 2
# 95  13/07/2020 21:22   19             Nursing                      Year 3
# 96  13/07/2020 21:23   23     Pendidikan Islam                     year 4
# 97  18/07/2020 20:16   20   Biomedical science                     Year 2
#
#    Do you have Anxiety? Do you have Panic attack?  \
# ...

# %%
X = df[['Choose your gender_res', 'Age', 'What is your CGPA?_0 - 1.99', 'Marital status_res', 'What is your CGPA?_2.00 - 2.49', 'What is your CGPA?_2.50 - 2.99', 'What is your CGPA?_3.00 - 3.49', 'What is your CGPA?_3.50 - 4.00', ]]
y = df['Do you have Depression?_res']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0)

# %% [markdown]
# # Logistic Regression:

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression().fit(X_train, y_train)
lr_predict = lr.predict(X_test)
print('Student Mental Health')
print('Accuracy of Logistic regression classifier on train set:' , lr.score(X_train, y_train))
print('Accuracy of Logistic regression classifier on test set:' , lr.score(X_test, y_test))
# Out:
# Student Mental Health
# Accuracy of Logistic regression classifier on train set: 0.8356164383561644
# Accuracy of Logistic regression classifier on test set: 0.72

# %%
from sklearn.metrics import confusion_matrix

confusion = confusion_matrix(y_test, lr_predict)
print('Support vector machine classifier\n', confusion)
# Out:
# Support vector machine classifier
#  [[16  0]
#  [ 7  2]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, lr_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82        16
#            1       1.00      0.22      0.36         9
#
#     accuracy                           0.72        25
#    macro avg       0.85      0.61      0.59        25
# weighted avg       0.81      0.72      0.66        25

# %% [markdown]
# # Linear SVM:

# %%
from sklearn.svm import LinearSVC

lsvm = LinearSVC().fit(X_train, y_train)
lsvm_predicted = lsvm.predict(X_test)
print('Student Mental Health')
print('Accuracy of Linear SVC classifier on training set: {:.2f}'
     .format(lsvm.score(X_train, y_train)))
print('Accuracy of Linear SVC classifier on test set: {:.2f}'
     .format(lsvm.score(X_test, y_test)))
# Out:
# Student Mental Health
# Accuracy of Linear SVC classifier on training set: 0.81
# Accuracy of Linear SVC classifier on test set: 0.80
# c:\Users\zeina\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
confusion = confusion_matrix(y_test, lsvm_predicted)
print('Support vector machine classifier\n', confusion)
# Out:
# Support vector machine classifier
#  [[16  0]
#  [ 5  4]]

# %%
print(classification_report(y_test, lsvm_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86        16
#            1       1.00      0.44      0.62         9
#
#     accuracy                           0.80        25
#    macro avg       0.88      0.72      0.74        25
# weighted avg       0.85      0.80      0.78        25

# %% [markdown]
# # SVM with C:

# %%
svmc = LinearSVC(C=0.01).fit(X_train, y_train)
svmc_predicted = svmc.predict(X_test)
print('Student Mental Health')
print('Accuracy of SVC with parameter C=0.01 on training set: {:.2f}'
     .format(svmc.score(X_train, y_train)))
print('Accuracy of SVC with parameter C=0.01 on test set: {:.2f}'
     .format(svmc.score(X_test, y_test)))
# Out:
# Student Mental Health
# Accuracy of SVC with parameter C=0.01 on training set: 0.66
# Accuracy of SVC with parameter C=0.01 on test set: 0.64

# %%
confusion = confusion_matrix(y_test, svmc_predicted)
print('Support vector machine classifier\n', confusion)
# Out:
# Support vector machine classifier
#  [[16  0]
#  [ 9  0]]

# %%
svmc2 = LinearSVC(C=0.1).fit(X_train, y_train)
svmc2_predicted = svmc2.predict(X_test)
print('Student Mental Health')
print('Accuracy of SVC with parameter C=0.1 on training set: {:.2f}'
     .format(svmc2.score(X_train, y_train)))
print('Accuracy of SVC with parameter C=0.1 on test set: {:.2f}'
     .format(svmc2.score(X_test, y_test)))
# Out:
# Student Mental Health
# Accuracy of SVC with parameter C=0.1 on training set: 0.84
# Accuracy of SVC with parameter C=0.1 on test set: 0.72
# c:\Users\zeina\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
confusion = confusion_matrix(y_test, svmc2_predicted)
print('Support vector machine classifier\n', confusion)
# Out:
# Support vector machine classifier
#  [[16  0]
#  [ 7  2]]

# %%
print(classification_report(y_test, svmc2_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82        16
#            1       1.00      0.22      0.36         9
#
#     accuracy                           0.72        25
#    macro avg       0.85      0.61      0.59        25
# weighted avg       0.81      0.72      0.66        25

# %% [markdown]
# # SVM with gamma:

# %%
from sklearn.svm import SVC

svmg = SVC(kernel = 'rbf', gamma=0.01).fit(X_train, y_train)
svmg_predict = svmg.predict(X_test)
print('Student Mental Health')
print('Accuracy of Linear SVC with gamma=0.01 on training set: {:.2f}'
     .format(svmg.score(X_train, y_train)))
print('Accuracy of Linear SVC with gamma=0.01 on test set: {:.2f}'
     .format(svmg.score(X_test, y_test)))
# Out:
# Student Mental Health
# Accuracy of Linear SVC with gamma=0.01 on training set: 0.66
# Accuracy of Linear SVC with gamma=0.01 on test set: 0.64

# %%
confusion = confusion_matrix(y_test, svmg_predict)
print('Support vector machine classifier\n', confusion)
# Out:
# Support vector machine classifier
#  [[16  0]
#  [ 9  0]]

# %%
print(classification_report(y_test, svmg_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      1.00      0.78        16
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.64        25
#    macro avg       0.32      0.50      0.39        25
# weighted avg       0.41      0.64      0.50        25
# c:\Users\zeina\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\zeina\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(y_test, svmg_predict)
closest_zero = np.argmin(np.abs(thresholds))
closest_zero_p = precision[closest_zero]
closest_zero_r = recall[closest_zero]

plt.figure()
plt.xlim([0.0, 1.01])
plt.ylim([0.0, 1.01])
plt.plot(precision, recall, label='Precision-Recall Curve')
plt.plot(closest_zero_p, closest_zero_r, 'o', markersize = 12, fillstyle = 'none', c='r', mew=3)
plt.xlabel('Precision', fontsize=16)
plt.ylabel('Recall', fontsize=16)
plt.show()

# %%
svmg2 = SVC(kernel = 'rbf', gamma=1).fit(X_train, y_train)
svmg2_predict = svmg2.predict(X_test)
print('Student Mental Health')
print('Accuracy of Linear SVC with gamma=1 on training set: {:.2f}'
     .format(svmg2.score(X_train, y_train)))
print('Accuracy of Linear SVC with gamma=1 on test set: {:.2f}'
     .format(svmg2.score(X_test, y_test)))
# Out:
# Student Mental Health
# Accuracy of Linear SVC with gamma=1 on training set: 0.85
# Accuracy of Linear SVC with gamma=1 on test set: 0.72

# %%
confusion = confusion_matrix(y_test, svmg2_predict)
print('Support vector machine classifier\n', confusion)
# Out:
# Support vector machine classifier
#  [[16  0]
#  [ 7  2]]

# %%
print(classification_report(y_test, svmg2_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82        16
#            1       1.00      0.22      0.36         9
#
#     accuracy                           0.72        25
#    macro avg       0.85      0.61      0.59        25
# weighted avg       0.81      0.72      0.66        25

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(y_test, svmg2_predict)
closest_zero = np.argmin(np.abs(thresholds))
closest_zero_p = precision[closest_zero]
closest_zero_r = recall[closest_zero]

plt.figure()
plt.xlim([0.0, 1.01])
plt.ylim([0.0, 1.01])
plt.plot(precision, recall, label='Precision-Recall Curve')
plt.plot(closest_zero_p, closest_zero_r, 'o', markersize = 12, fillstyle = 'none', c='r', mew=3)
plt.xlabel('Precision', fontsize=16)
plt.ylabel('Recall', fontsize=16)
plt.show()

# %% [markdown]
# # SVM with C and gamma:

# %%
svmcg = SVC(kernel = 'rbf', gamma = 0.01, C = 0.01).fit(X_train, y_train)
svmcg_predict = svmcg.predict(X_test)
print('Student Mental Health')
print('Accuracy of Linear SVC with gamma=0.01 and c=0.01 on training set: {:.2f}'
     .format(svmcg.score(X_train, y_train)))
print('Accuracy of Linear SVC with gamma=0.01 and c=0.01 on test set: {:.2f}'
     .format(svmcg.score(X_test, y_test)))
# Out:
# Student Mental Health
# Accuracy of Linear SVC with gamma=0.01 and c=0.01 on training set: 0.66
# Accuracy of Linear SVC with gamma=0.01 and c=0.01 on test set: 0.64

# %%
confusion = confusion_matrix(y_test, svmcg_predict)
print('Support vector machine classifier\n', confusion)
# Out:
# Support vector machine classifier
#  [[16  0]
#  [ 9  0]]

# %%
svmcg2 = SVC(kernel = 'rbf', gamma = 1, C = 1).fit(X_train, y_train)
svmcg2_predict = svmcg2.predict(X_test)
print('Student Mental Health')
print('Accuracy of Linear SVC with gamma=1 and c=1 on training set: {:.2f}'
     .format(svmcg2.score(X_train, y_train)))
print('Accuracy of Linear SVC with gamma=1 and c=1 on test set: {:.2f}'
     .format(svmcg2.score(X_test, y_test)))
# Out:
# Student Mental Health
# Accuracy of Linear SVC with gamma=1 and c=1 on training set: 0.85
# Accuracy of Linear SVC with gamma=1 and c=1 on test set: 0.72

# %%
confusion = confusion_matrix(y_test, svmcg2_predict)
print('Support vector machine classifier\n', confusion)
# Out:
# Support vector machine classifier
#  [[16  0]
#  [ 7  2]]

# %%
print(classification_report(y_test, svmg2_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82        16
#            1       1.00      0.22      0.36         9
#
#     accuracy                           0.72        25
#    macro avg       0.85      0.61      0.59        25
# weighted avg       0.81      0.72      0.66        25

# %% [markdown]
# # SVM with normalized data:

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

nsvm = SVC(C=0.1).fit(X_train_scaled, y_train)
nsvm_predict = nsvm.predict(X_test)
print('Student Mental Health')
print('RBF-kernel SVC (with MinMax scaling) training set accuracy: {:.2f}'
     .format(nsvm.score(X_train_scaled, y_train)))
print('RBF-kernel SVC (with MinMax scaling) test set accuracy: {:.2f}'
     .format(nsvm.score(X_test_scaled, y_test)))
# Out:
# Student Mental Health
# RBF-kernel SVC (with MinMax scaling) training set accuracy: 0.66
# RBF-kernel SVC (with MinMax scaling) test set accuracy: 0.64
# c:\Users\zeina\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(

# %%
confusion = confusion_matrix(y_test, nsvm_predict)
print('Support vector machine classifier\n', confusion)
# Out:
# Support vector machine classifier
#  [[16  0]
#  [ 9  0]]

# %%
print(classification_report(y_test, nsvm_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      1.00      0.78        16
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.64        25
#    macro avg       0.32      0.50      0.39        25
# weighted avg       0.41      0.64      0.50        25
# c:\Users\zeina\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\zeina\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # Decision Tree:

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier().fit(X_train, y_train)
print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(dtc.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on testing set: {:.2f}'
     .format(dtc.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on training set: 0.85
# Accuracy of Decision Tree classifier on testing set: 0.76

# %%
plt.barh(range(8), dtc.feature_importances_, align='center')
plt.yticks(np.arange(8), ['Choose your gender_res', 'Age', 'What is your CGPA?_0 - 1.99', 'Marital status_res', 'What is your CGPA?_2.00 - 2.49', 'What is your CGPA?_2.50 - 2.99', 'What is your CGPA?_3.00 - 3.49', 'What is your CGPA?_3.50 - 4.00', ])
plt.show()

# %%
from sklearn import tree
import graphviz
dot_data = tree.export_graphviz(dtc, out_file='dct1.dot',
                                feature_names=['Choose your gender_res', 'Age', 'What is your CGPA?_0 - 1.99', 'Marital status_res', 'What is your CGPA?_2.00 - 2.49', 'What is your CGPA?_2.50 - 2.99', 'What is your CGPA?_3.00 - 3.49', 'What is your CGPA?_3.50 - 4.00', ],
                                class_names=['Yes', 'No'],
                                filled=True, rounded=True,
                                special_characters=True)
with open('dct1.dot') as f:
    dot_graph = f.read()
graph = graphviz.Source(dot_graph)
graph

# %% [markdown]
# # Decision Tree with max_depth:

# %%
dtcm = DecisionTreeClassifier(max_depth=2).fit(X_train, y_train)
print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(dtcm.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on testing set: {:.2f}'
     .format(dtcm.score(X_test, y_test)))
dtcm.feature_importances_
# Out:
# Accuracy of Decision Tree classifier on training set: 0.84
# Accuracy of Decision Tree classifier on testing set: 0.72
# array([0.  , 0.12, 0.  , 0.88, 0.  , 0.  , 0.  , 0.  ])

# %%
dot_data = tree.export_graphviz(dtcm, out_file='dct2.dot',
                                feature_names=['Choose your gender_res', 'Age', 'What is your CGPA?_0 - 1.99', 'Marital status_res', 'What is your CGPA?_2.00 - 2.49', 'What is your CGPA?_2.50 - 2.99', 'What is your CGPA?_3.00 - 3.49', 'What is your CGPA?_3.50 - 4.00', ],
                                class_names=['Yes', 'No'],
                                filled=True, rounded=True,
                                special_characters=True)
with open('dct2.dot') as f:
    dot_graph = f.read()
graph = graphviz.Source(dot_graph)
graph

# %%
dtcm2 = DecisionTreeClassifier(max_depth=5).fit(X_train, y_train)
print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(dtcm2.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on testing set: {:.2f}'
     .format(dtcm2.score(X_test, y_test)))
dtcm2.feature_importances_
# Out:
# Accuracy of Decision Tree classifier on training set: 0.85
# Accuracy of Decision Tree classifier on testing set: 0.76
# array([0.04, 0.17, 0.  , 0.73, 0.  , 0.02, 0.04, 0.  ])

# %%
dot_data = tree.export_graphviz(dtcm2, out_file='dct3.dot',
                                feature_names=['Choose your gender_res', 'Age', 'What is your CGPA?_0 - 1.99', 'Marital status_res', 'What is your CGPA?_2.00 - 2.49', 'What is your CGPA?_2.50 - 2.99', 'What is your CGPA?_3.00 - 3.49', 'What is your CGPA?_3.50 - 4.00', ],
                                class_names=['Yes', 'No'],
                                filled=True, rounded=True,
                                special_characters=True)
with open('dct3.dot') as f:
    dot_graph = f.read()
graph = graphviz.Source(dot_graph)
graph

# %% [markdown]
# # KNN (k-nearest neighbor):

# %%
from sklearn.neighbors import KNeighborsClassifier

knn= KNeighborsClassifier(n_neighbors=2)  
knn.fit(X_train, y_train)
knn_predict = knn.predict(X_test)
print('Accuracy of KNN classifier on training set: {:.2f}'
     .format(knn.score(X_train, y_train)))
print('Accuracy of KNN classifier on testing set: {:.2f}'
     .format(knn.score(X_test, y_test)))
# Out:
# Accuracy of KNN classifier on training set: 0.77
# Accuracy of KNN classifier on testing set: 0.72
# c:\Users\zeina\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
confusion = confusion_matrix(y_test, knn_predict)
print('k-nearest neighbor\n', confusion)
# Out:
# k-nearest neighbor
#  [[16  0]
#  [ 7  2]]

# %%
print(classification_report(y_test, knn_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82        16
#            1       1.00      0.22      0.36         9
#
#     accuracy                           0.72        25
#    macro avg       0.85      0.61      0.59        25
# weighted avg       0.81      0.72      0.66        25

# %% [markdown]
# # Random Forest:

# %%
from sklearn.ensemble import RandomForestClassifier

#n_estimator is the number of trees
rf = RandomForestClassifier(n_estimators= 10)  
rf.fit(X_train, y_train) 
rf_predict = rf.predict(X_test)
print('Accuracy of Random Forest classifier on training set: {:.2f}'
     .format(rf.score(X_train, y_train)))
print('Accuracy of Random Forest classifier on testing set: {:.2f}'
     .format(rf.score(X_test, y_test)))
# Out:
# Accuracy of Random Forest classifier on training set: 0.85
# Accuracy of Random Forest classifier on testing set: 0.76

# %%
confusion = confusion_matrix(y_test, rf_predict)
print('k-nearest neighbor\n', confusion)
# Out:
# k-nearest neighbor
#  [[16  0]
#  [ 6  3]]

# %%
print(classification_report(y_test, rf_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      1.00      0.84        16
#            1       1.00      0.33      0.50         9
#
#     accuracy                           0.76        25
#    macro avg       0.86      0.67      0.67        25
# weighted avg       0.83      0.76      0.72        25

# %%
from sklearn.metrics import roc_curve, auc
from matplotlib import cm

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

plt.figure()
plt.xlim([-0.01, 1.00])
plt.ylim([-0.01, 1.01])
for g in [0.01, 0.1, 0.20, 1]:
    svm = SVC(gamma=g).fit(X_train, y_train)
    y_score_svm = svm.decision_function(X_test)
    fpr_svm, tpr_svm, _ = roc_curve(y_test, y_score_svm)
    roc_auc_svm = auc(fpr_svm, tpr_svm)
    accuracy_svm = svm.score(X_test, y_test)
    print("gamma = {:.2f}  accuracy = {:.2f}   AUC = {:.2f}".format(g, accuracy_svm, 
                                                                    roc_auc_svm))
    plt.plot(fpr_svm, tpr_svm, lw=3, alpha=0.7, 
             label='SVM (gamma = {:0.2f}, area = {:0.2f})'.format(g, roc_auc_svm))

plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate (Recall)', fontsize=16)
plt.plot([0, 1], [0, 1], color='k', lw=0.5, linestyle='--')
plt.legend(loc="lower right", fontsize=11)
plt.title('ROC curve: (1-of-10 digits classifier)', fontsize=16)
plt.show()
# Out:
# gamma = 0.01  accuracy = 0.64   AUC = 0.69
# gamma = 0.10  accuracy = 0.68   AUC = 0.64
# gamma = 0.20  accuracy = 0.72   AUC = 0.45
# gamma = 1.00  accuracy = 0.72   AUC = 0.50

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score


clf = SVC(kernel='rbf')
grid_values = {'gamma': [0.001, 0.01, 0.05, 0.1, 1, 10, 100]}

# default metric to optimize over grid parameters: accuracy
grid_clf_acc = GridSearchCV(clf, param_grid = grid_values)
grid_clf_acc.fit(X_train, y_train)
y_decision_fn_scores_acc = grid_clf_acc.decision_function(X_test) 

print('Grid best parameter (max. accuracy): ', grid_clf_acc.best_params_)
print('Grid best score (accuracy): ', grid_clf_acc.best_score_)

# alternative metric to optimize over grid parameters: AUC
grid_clf_auc = GridSearchCV(clf, param_grid = grid_values, scoring = 'roc_auc')
grid_clf_auc.fit(X_train, y_train)
y_decision_fn_scores_auc = grid_clf_auc.decision_function(X_test) 

print('Test set AUC: ', roc_auc_score(y_test, y_decision_fn_scores_auc))
print('Grid best parameter (max. AUC): ', grid_clf_auc.best_params_)
print('Grid best score (AUC): ', grid_clf_auc.best_score_)
# Out:
# Grid best parameter (max. accuracy):  {'gamma': 1}
# Grid best score (accuracy):  0.7561904761904763
# Test set AUC:  0.6909722222222222
# Grid best parameter (max. AUC):  {'gamma': 0.01}
# Grid best score (AUC):  0.7975555555555556
